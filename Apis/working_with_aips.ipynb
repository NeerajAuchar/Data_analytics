# %%
base_url = "https://v6.exchangerate-api.com/v6/f313b0f1d63757b5ae4df40a/latest/USD"

# %%
import requests

# %%
responce = requests.get(base_url)
responce
# Out:
# <Response [200]>

# %%
responce.ok
# Out:
# True

# %%
responce.status_code
# Out:
# 200

# %%
responce.text
# Out:
# '{\n "result":"success",\n "documentation":"https://www.exchangerate-api.com/docs",\n "terms_of_use":"https://www.exchangerate-api.com/terms",\n "time_last_update_unix":1707523201,\n "time_last_update_utc":"Sat, 10 Feb 2024 00:00:01 +0000",\n "time_next_update_unix":1707609601,\n "time_next_update_utc":"Sun, 11 Feb 2024 00:00:01 +0000",\n "base_code":"USD",\n "conversion_rates":{\n  "USD":1,\n  "AED":3.6725,\n  "AFN":73.8106,\n  "ALL":96.8658,\n  "AMD":405.1027,\n  "ANG":1.7900,\n  "AOA":837.1213,\n  "ARS":831.2500,\n  "AUD":1.5339,\n  "AWG":1.7900,\n  "AZN":1.7004,\n  "BAM":1.8147,\n  "BBD":2.0000,\n  "BDT":109.7370,\n  "BGN":1.8148,\n  "BHD":0.3760,\n  "BIF":2844.1048,\n  "BMD":1.0000,\n  "BND":1.3464,\n  "BOB":6.9366,\n  "BRL":4.9735,\n  "BSD":1.0000,\n  "BTN":83.0404,\n  "BWP":13.7300,\n  "BYN":3.2476,\n  "BZD":2.0000,\n  "CAD":1.3455,\n  "CDF":2695.9599,\n  "CHF":0.8750,\n  "CLP":963.9572,\n  "CNY":7.2071,\n  "COP":3957.5825,\n  "CRC":517.7838,\n  "CUP":24.0000,\n  "CVE":102.307
# ...

# %%
responce.content
# Out:
# b'{\n "result":"success",\n "documentation":"https://www.exchangerate-api.com/docs",\n "terms_of_use":"https://www.exchangerate-api.com/terms",\n "time_last_update_unix":1707523201,\n "time_last_update_utc":"Sat, 10 Feb 2024 00:00:01 +0000",\n "time_next_update_unix":1707609601,\n "time_next_update_utc":"Sun, 11 Feb 2024 00:00:01 +0000",\n "base_code":"USD",\n "conversion_rates":{\n  "USD":1,\n  "AED":3.6725,\n  "AFN":73.8106,\n  "ALL":96.8658,\n  "AMD":405.1027,\n  "ANG":1.7900,\n  "AOA":837.1213,\n  "ARS":831.2500,\n  "AUD":1.5339,\n  "AWG":1.7900,\n  "AZN":1.7004,\n  "BAM":1.8147,\n  "BBD":2.0000,\n  "BDT":109.7370,\n  "BGN":1.8148,\n  "BHD":0.3760,\n  "BIF":2844.1048,\n  "BMD":1.0000,\n  "BND":1.3464,\n  "BOB":6.9366,\n  "BRL":4.9735,\n  "BSD":1.0000,\n  "BTN":83.0404,\n  "BWP":13.7300,\n  "BYN":3.2476,\n  "BZD":2.0000,\n  "CAD":1.3455,\n  "CDF":2695.9599,\n  "CHF":0.8750,\n  "CLP":963.9572,\n  "CNY":7.2071,\n  "COP":3957.5825,\n  "CRC":517.7838,\n  "CUP":24.0000,\n  "CVE":102.30
# ...

# %%
responce.json()
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1707523201,
#  'time_last_update_utc': 'Sat, 10 Feb 2024 00:00:01 +0000',
#  'time_next_update_unix': 1707609601,
#  'time_next_update_utc': 'Sun, 11 Feb 2024 00:00:01 +0000',
#  'base_code': 'USD',
#  'conversion_rates': {'USD': 1,
#   'AED': 3.6725,
#   'AFN': 73.8106,
#   'ALL': 96.8658,
#   'AMD': 405.1027,
#   'ANG': 1.79,
#   'AOA': 837.1213,
#   'ARS': 831.25,
#   'AUD': 1.5339,
#   'AWG': 1.79,
#   'AZN': 1.7004,
#   'BAM': 1.8147,
#   'BBD': 2.0,
#   'BDT': 109.737,
#   'BGN': 1.8148,
#   'BHD': 0.376,
#   'BIF': 2844.1048,
#   'BMD': 1.0,
#   'BND': 1.3464,
#   'BOB': 6.9366,
#   'BRL': 4.9735,
#   'BSD': 1.0,
#   'BTN': 83.0404,
#   'BWP': 13.73,
#   'BYN': 3.2476,
#   'BZD': 2.0,
#   'CAD': 1.3455,
#   'CDF': 2695.9599,
#   'CHF': 0.875,
#   'CLP': 963.9572,
#   'CNY': 7.2071,
#   'COP': 3957.5825,
# ...

# %%
type(responce.json())
# Out:
# dict

# %%
import json

# %%
json.dumps(responce.json(), indent=4)
# Out:
# '{\n    "result": "success",\n    "documentation": "https://www.exchangerate-api.com/docs",\n    "terms_of_use": "https://www.exchangerate-api.com/terms",\n    "time_last_update_unix": 1707523201,\n    "time_last_update_utc": "Sat, 10 Feb 2024 00:00:01 +0000",\n    "time_next_update_unix": 1707609601,\n    "time_next_update_utc": "Sun, 11 Feb 2024 00:00:01 +0000",\n    "base_code": "USD",\n    "conversion_rates": {\n        "USD": 1,\n        "AED": 3.6725,\n        "AFN": 73.8106,\n        "ALL": 96.8658,\n        "AMD": 405.1027,\n        "ANG": 1.79,\n        "AOA": 837.1213,\n        "ARS": 831.25,\n        "AUD": 1.5339,\n        "AWG": 1.79,\n        "AZN": 1.7004,\n        "BAM": 1.8147,\n        "BBD": 2.0,\n        "BDT": 109.737,\n        "BGN": 1.8148,\n        "BHD": 0.376,\n        "BIF": 2844.1048,\n        "BMD": 1.0,\n        "BND": 1.3464,\n        "BOB": 6.9366,\n        "BRL": 4.9735,\n        "BSD": 1.0,\n        "BTN": 83.0404,\n        "BWP": 13.73,\n        "BY
# ...

# %%
print(json.dumps(responce.json(), indent=4))
# Out:
# {
#     "result": "success",
#     "documentation": "https://www.exchangerate-api.com/docs",
#     "terms_of_use": "https://www.exchangerate-api.com/terms",
#     "time_last_update_unix": 1707523201,
#     "time_last_update_utc": "Sat, 10 Feb 2024 00:00:01 +0000",
#     "time_next_update_unix": 1707609601,
#     "time_next_update_utc": "Sun, 11 Feb 2024 00:00:01 +0000",
#     "base_code": "USD",
#     "conversion_rates": {
#         "USD": 1,
#         "AED": 3.6725,
#         "AFN": 73.8106,
#         "ALL": 96.8658,
#         "AMD": 405.1027,
#         "ANG": 1.79,
#         "AOA": 837.1213,
#         "ARS": 831.25,
#         "AUD": 1.5339,
#         "AWG": 1.79,
#         "AZN": 1.7004,
#         "BAM": 1.8147,
#         "BBD": 2.0,
#         "BDT": 109.737,
#         "BGN": 1.8148,
#         "BHD": 0.376,
#         "BIF": 2844.1048,
#         "BMD": 1.0,
#         "BND": 1.3464,
#         "BOB": 6.9366,
#         "BRL": 4.9735,
#         "BSD": 1.0,
#         "BTN": 83.0404,
# ...

# %%
responce.json().keys()
# Out:
# dict_keys(['result', 'documentation', 'terms_of_use', 'time_last_update_unix', 'time_last_update_utc', 'time_next_update_unix', 'time_next_update_utc', 'base_code', 'conversion_rates'])

# %%
param_url = base_url + "pair=USD,GBP"
param_url
# Out:
# 'https://v6.exchangerate-api.com/v6/f313b0f1d63757b5ae4df40a/latest/USDpair=USD,GBP'

# %%
responce = requests.get(param_url)
responce
# Out:
# <Response [404]>

# %%
responce.text
# Out:
# '{\n "result":"success",\n "documentation":"https://www.exchangerate-api.com/docs",\n "terms_of_use":"https://www.exchangerate-api.com/terms",\n "time_last_update_unix":1707523201,\n "time_last_update_utc":"Sat, 10 Feb 2024 00:00:01 +0000",\n "time_next_update_unix":1707609601,\n "time_next_update_utc":"Sun, 11 Feb 2024 00:00:01 +0000",\n "base_code":"USD",\n "conversion_rates":{\n  "USD":1,\n  "AED":3.6725,\n  "AFN":73.8106,\n  "ALL":96.8658,\n  "AMD":405.1027,\n  "ANG":1.7900,\n  "AOA":837.1213,\n  "ARS":831.2500,\n  "AUD":1.5339,\n  "AWG":1.7900,\n  "AZN":1.7004,\n  "BAM":1.8147,\n  "BBD":2.0000,\n  "BDT":109.7370,\n  "BGN":1.8148,\n  "BHD":0.3760,\n  "BIF":2844.1048,\n  "BMD":1.0000,\n  "BND":1.3464,\n  "BOB":6.9366,\n  "BRL":4.9735,\n  "BSD":1.0000,\n  "BTN":83.0404,\n  "BWP":13.7300,\n  "BYN":3.2476,\n  "BZD":2.0000,\n  "CAD":1.3455,\n  "CDF":2695.9599,\n  "CHF":0.8750,\n  "CLP":963.9572,\n  "CNY":7.2071,\n  "COP":3957.5825,\n  "CRC":517.7838,\n  "CUP":24.0000,\n  "CVE":102.307
# ...

# %%
data = responce.json()

# %%
data
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1707523201,
#  'time_last_update_utc': 'Sat, 10 Feb 2024 00:00:01 +0000',
#  'time_next_update_unix': 1707609601,
#  'time_next_update_utc': 'Sun, 11 Feb 2024 00:00:01 +0000',
#  'base_code': 'USD',
#  'conversion_rates': {'USD': 1,
#   'AED': 3.6725,
#   'AFN': 73.8106,
#   'ALL': 96.8658,
#   'AMD': 405.1027,
#   'ANG': 1.79,
#   'AOA': 837.1213,
#   'ARS': 831.25,
#   'AUD': 1.5339,
#   'AWG': 1.79,
#   'AZN': 1.7004,
#   'BAM': 1.8147,
#   'BBD': 2.0,
#   'BDT': 109.737,
#   'BGN': 1.8148,
#   'BHD': 0.376,
#   'BIF': 2844.1048,
#   'BMD': 1.0,
#   'BND': 1.3464,
#   'BOB': 6.9366,
#   'BRL': 4.9735,
#   'BSD': 1.0,
#   'BTN': 83.0404,
#   'BWP': 13.73,
#   'BYN': 3.2476,
#   'BZD': 2.0,
#   'CAD': 1.3455,
#   'CDF': 2695.9599,
#   'CHF': 0.875,
#   'CLP': 963.9572,
#   'CNY': 7.2071,
#   'COP': 3957.5825,
# ...
