# %%
import json

# %%
data = {
    "pathological": {
        "margin_type": null,
        "margin_status": null,
        "invasion_information": null,
        "number_of_lymph_nodes_removed": "4",
        "number_of_lymph_nodes_positive": "0"
    },
    "biomarkers": [
        {
            "name": "ER",
            "biomarker_status": "positive",
            "biomarker_value": "3+, >95%"
        },
        {
            "name": "PR",
            "biomarker_status": "positive",
            "biomarker_value": "3+, >95%"
        },
        {
            "name": "HER2",
            "biomarker_status": "negative",
            "biomarker_value": null
        }
    ],
    "PS": {
        "ECOG": null,
        "Karnofsky": null,
        "AUA": null
    },
    "treatment": [
        {
            "treatment_step": null,
            "treatment_step_type": "anti-endocrine therapy",
            "status": "in progress",
            "drug_regimen": "arimidex"
        }
    ],
    "treatment_response": {
        "disease_status": null,
        "patient_toxicities": null
    },
    "tumors": [
        {
            "tumor_description": ".8 cm IMC with associated cribiform carcinoma, NST, low grade, low proliferative rate",
            "location": {
                "body_part": "right breast",
                "anatomical_descriptor": null
            },
            "histological_type": "NST",
            "histological_subtype": "cribiform carcinoma",
            "histological_grade": "low grade",
            "group_stage": "IA",
            "t_stage": null,
            "n_stage": null,
            "m_stage": null,
            "dimensions": {
                "value": ".8 cm",
                "unit_of_measure": "cm"
            }
        }
    ],
    "procedure": [
        {
            "name": "R mastectomy",
            "body_site": "right breast",
            "occurrence_date": "Mar 07 2011"
        }
    ],
    "imaging_procedure": [
        {
            "name": "CHEST CT WITHOUT CONTRAST",
            "body_sites": "chest",
            "occurrence_date": "Dec 04 2011",
            "imaging_orientations": null,
            "contrast": null
        }
    ],
    "family_history": [
        {
            "description": "Mother -died 68-Colon CA",
            "asserted_status": null,
            "timeframe": null
        },
        {
            "description": "Father died 76-enlarged heart,died in sleep, hx Afib",
            "asserted_status": null,
            "timeframe": null
        },
        {
            "description": "twin brother living-afib",
            "asserted_status": null,
            "timeframe": null
        },
        {
            "description": "Daughter-symptoms of afib, has not been treated",
            "asserted_status": null,
            "timeframe": null
        }
    ],
    "substance_history": [
        {
            "substance_item": "tobacco",
            "timeframe": null,
            "asserted_status": "denies"
        },
        {
            "substance_item": "ETOH",
            "timeframe": null,
            "asserted_status": "denies"
        },
        {
            "substance_item": "Caffeine",
            "timeframe": "2 cups coffee/day, 1 glasses ice tea/supper time",
            "asserted_status": null
        }
    ],
    "medications": [
        {
            "medication_name": "Calcium with Vitamin D",
            "route": "oral",
            "regimen": "once daily",
            "dosage_amount": "1200mg/1000 International Units",
            "dosage_uom": "tablet"
        },
        {
            "medication_name": "carvedilol",
            "route": "oral",
            "regimen": "twice a day",
            "dosage_amount": "12.5 mg",
            "dosage_uom": "tablet"
        },
        {
            "medication_name": "digoxin",
            "route": "oral",
            "regimen": "twice daily",
            "dosage_amount": "250 mcg",
            "dosage_uom": "tablet"
        },
        {
            "medication_name": "furosemide",
            "route": "oral",
            "regimen": "daily",
            "dosage_amount": "20 mg",
            "dosage_uom": "tablet"
        },
        {
            "medication_name": "omeprazole",
            "route": "oral",
            "regimen": "daily",
            "dosage_amount": "20 mg",
            "dosage_uom": "tablet,delayed release"
        },
        {
            "medication_name": "senna",
            "route": "oral",
            "regimen": "as needed",
            "dosage_amount": null,
            "dosage_uom": null
        },
        {
            "medication_name": "sertraline",
            "route": "oral",
            "regimen": "daily",
            "dosage_amount": "100 mg",
            "dosage_uom": "tablet"
        },
        {
            "medication_name": "simvastatin",
            "route": "oral",
            "regimen": "daily",
            "dosage_amount": "20 mg",
            "dosage_uom": "tablet"
        },
        {
            "medication_name": "amitriptyline",
            "route": "oral",
            "regimen": "every evening at bedtime",
            "dosage_amount": "25 mg",
            "dosage_uom": "tablet"
        },
        {
            "medication_name": "anastrozole",
            "route": "oral",
            "regimen": "daily",
            "dosage_amount": "1 mg",
            "dosage_uom": "tablet"
        },
        {
            "medication_name": "warfarin",
            "route": "oral",
            "regimen": "daily except take 1/2 tablet on Fri & Sun for atrial fib/flutter (or as directed by the **INSTITUTION)",
            "dosage_amount": "6 mg",
            "dosage_uom": "tablet"
        },
        {
            "medication_name": "Diovan (Valsartan)",
            "route": "oral",
            "regimen": "daily in the morning",
            "dosage_amount": "160 mg",
            "dosage_uom": "tablet"
        },
        {
            "medication_name": "buspirone",
            "route": "oral",
            "regimen": "twice a day",
            "dosage_amount": "15 mg",
            "dosage_uom": "tablet"
        },
        {
            "medication_name": "promethazine",
            "route": "oral",
            "regimen": "every 6 hours as needed for nausea, vomiting",
            "dosage_amount": "12.5 mg",
            "dosage_uom": "tablet"
        }
    ],
    "complaints": [
        {
            "complaint": "right breast bloody nipple discharge",
            "date": "Jul 2010"
        },
        {
            "complaint": "right breast mass",
            "date": "early 2011"
        }
    ],
    "findings": [
        "Tiny subpleural, noncalcified pulmonary nodules are stable since the previous PET CT in Jul 19 11 (given differences in technique).",
        "Postoperative changes from a right mastectomy and axillary lymph node dissection.",
        "Densely sclerotic bone lesion in T5 has been previously biopsied. No new bone lesion.",
        "Status post cholecystectomy and partial left nephrectomy."
    ]
    
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 data = {
#       2     "pathological": {
# ----> 3         "margin_type": null,
#       4         "margin_status": null,
#       5         "invasion_information": null,
#       6         "number_of_lymph_nodes_removed": "4",
#       7         "number_of_lymph_nodes_positive": "0"
#       8     },
#       9     "biomarkers": [
#      10         {
#      11             "name": "ER",
#      12             "biomarker_status": "positive",
#      13             "biomarker_value": "3+, >95%"
#      14         },
#      15         {
#      16             "name": "PR",
#      17             "biomarker_status": "positive",
#      18             "biomarker_value": "3+, >95%"
#      19         },
#      20         {
#      21             "name": "HER2",
#      22             "biomarker_status": "negative",
# ...
